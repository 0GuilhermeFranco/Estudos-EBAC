# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
#Primeiramente , optei por criar o mesmo df apresentado acima, podendo acessar os valores posteriormente no cod.
assuntos = ['Matemática','Português','Geografia','Inglês','História','Física','Química']
qnt_questoes = [24,18,8,8,8,12,12]
df_questoes = pd.DataFrame({'Quantidade_Questões':qnt_questoes},index=assuntos)

#Também achei mais prático ter um dataframe com todos os acertos e todoas as matérias
df_acertos = pd.concat([df_mat, df_por, df_geo, df_ing, df_his, df_fis, df_qui], axis=1)
df_acertos.columns = ['Matemática', 'Português', 'Geografia', 'Inglês', 'História', 'Física', 'Química']

# %%
# 1) Seu código aqui
#aqui dividimos o df acertos pelo df de quantidade de questões e já multiplicamos por 100 afim de conseguir porcentagem
df_percentual_acertos = df_acertos.div(df_questoes['Quantidade_Questões'], axis=1) * 100
df_percentual_acertos
# Out:
#     Matemática  Português  Geografia  Inglês  História     Física    Química
# 0    25.000000  38.888889       87.5    37.5      12.5  66.666667  25.000000
# 1    79.166667  55.555556        0.0     0.0       0.0  91.666667  66.666667
# 2    58.333333  88.888889        0.0    62.5      87.5  33.333333  33.333333
# 3    41.666667  38.888889       37.5    50.0       0.0   0.000000  66.666667
# 4    29.166667  11.111111       25.0    87.5       0.0  75.000000  25.000000
# ..         ...        ...        ...     ...       ...        ...        ...
# 95   25.000000  22.222222       87.5    12.5      50.0  75.000000  25.000000
# 96   33.333333   5.555556       50.0    75.0      12.5  33.333333  25.000000
# 97   95.833333  27.777778        0.0    25.0      50.0   8.333333  41.666667
# 98    0.000000  55.555556       37.5    12.5      62.5  83.333333  91.666667
# 99   45.833333  83.333333        0.0    12.5      75.0  58.333333  16.666667
#
# [100 rows x 7 columns]

# %%
# 2) Seu código aqui
#aqui calculamos o total de acertos e acrescentamos isso a uma nova coluna
df_acertos['Total_Acertos'] = df_acertos.sum(axis=1)
df_acertos
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 0            6          7          7       3         1       8        3
# 1           19         10          0       0         0      11        8
# 2           14         16          0       5         7       4        4
# 3           10          7          3       4         0       0        8
# 4            7          2          2       7         0       9        3
# ..         ...        ...        ...     ...       ...     ...      ...
# 95           6          4          7       1         4       9        3
# 96           8          1          4       6         1       4        3
# 97          23          5          0       2         4       1        5
# 98           0         10          3       1         5      10       11
# 99          11         15          0       1         6       7        2
#
#     Total_Acertos
# 0              35
# 1              48
# 2              50
# 3              32
# ...

# %%
# 3) Seu código aqui
#
total_questoes = df_questoes['Quantidade_Questões'].sum()

df_acertos['Percentual_Geral'] = (df_acertos['Total_Acertos'] / total_questoes) * 100

df_acertos.head()
# Out:
#    Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 0           6          7          7       3         1       8        3
# 1          19         10          0       0         0      11        8
# 2          14         16          0       5         7       4        4
# 3          10          7          3       4         0       0        8
# 4           7          2          2       7         0       9        3
#
#    Total_Acertos  Percentual_Geral
# 0             35         38.888889
# 1             48         53.333333
# 2             50         55.555556
# 3             32         35.555556
# 4             30         33.333333

# %%
# 4) Seu código aqui
alunos_aprovados = df_acertos[df_acertos['Total_Acertos'] > 45]
alunos_aprovados
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 1           19         10          0       0         0      11        8
# 2           14         16          0       5         7       4        4
# 5           20          2          5       3         2       9        9
# 7           18          4          4       7         7       1        8
# 8           22          9          2       7         6       5        7
# 17          21         15          2       2         4       2        6
# 18          20          4          3       5         3      11        4
# 20          23         11          6       5         6       2        0
# 24          20          2          7       5         3      11        2
# 27          21         13          1       5         7       3        0
# 31          15         13          3       1         3       9       10
# 35          11         14          6       3         3       0       11
# ...

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
#1) seu código aqui
#aqui vamos filtrar quem zerou em matemática, física ou química, dentro os alunos aprovados(acima da média de 45 acertos)
alunos_desqualificados =  df_acertos[(df_acertos['Matemática'] == 0) | 
                                     (df_acertos['Física']     == 0) | 
                                     (df_acertos['Química']    == 0) ]
alunos_desqualificados
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 3           10          7          3       4         0       0        8
# 6            6          0          7       7         5       0        4
# 10          10          8          3       2         1       7        0
# 12          20          8          3       7         1       0        3
# 14           7         11          1       7         1       4        0
# 20          23         11          6       5         6       2        0
# 25           0          4          7       4         0       4        8
# 26          11         14          6       2         7       0        0
# 27          21         13          1       5         7       3        0
# 33          14          8          0       5         6       6        0
# 35          11         14          6       3         3       0       11
# 49           8          1          1       0         1       0        8
# ...

# %%
#2) seu código aqui
#aqui vamos ver o "comprimento" das linhas para contarmos quantos alunos temos nesse df já filtrado com os desclassificados
nmr_alunos_desqualificados = len(alunos_desqualificados)
nmr_alunos_desqualificados
# Out:
# 23

# %%
#3) seu código aqui
#aqui filtramos as variáveis que queremos do df e usamos .mean para obtermos uma média desses valores
m_a_desql_hist_geo = alunos_desqualificados[['História','Geografia']].mean()
m_a_desql_hist_geo
# Out:
# História     3.434783
# Geografia    3.217391
# dtype: float64

# %%
#4) seu código aqui
segunda_fase = alunos_aprovados - alunos_desqualificados

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
#para esse exercício, eu fui até o site indicado e baixei a base de dados part1 do acre, pois o trazer o link diretamente não funcionou.

df = pd.read_csv('part-00000-b666e24f-b8d2-4194-be7a-f15c5773e434.c000.csv', sep=';')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390911 entries, 0 to 390910
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   document_id                               390911 non-null  object
#  1   paciente_id                               390911 non-null  object
#  2   paciente_idade                            390911 non-null  int64
#  3   paciente_dataNascimento                   390911 non-null  object
#  4   paciente_enumSexoBiologico                390911 non-null  object
#  5   paciente_racaCor_codigo                   390911 non-null  int64
#  6   paciente_racaCor_valor                    390911 non-null  object
#  7   paciente_endereco_coIbgeMunicipio         388458 non-null  float64
#  8   paciente_endereco_coPais                  388464 non-null  float64
#  9   paciente_endereco_nmMunicipio             388463 non-null  object
# ...

# %%
#criei esse subset para ver melhor as idenficações unicas do estabelecimento
df_subset = df[['estabelecimento_valor','estabelecimento_razaoSocial','estalecimento_noFantasia','estabelecimento_municipio_codigo','estabelecimento_municipio_nome','estabelecimento_uf']]
df_subset.head(15)
# Out:
#     estabelecimento_valor              estabelecimento_razaoSocial  \
# 0                 6159087  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 1                 2000016  PREFEITURA MUNICIPAL DE RODRIGUES ALVES
# 2                 2001349        PREFEITURA MUNICIPAL DE BRASILEIA
# 3                 6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 4                 6992811   PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 5                 6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 6                 6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 7                 6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 8                 2002922            SECRETARIA MUNICIPAL DE SAUDE
# 9                 6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 10                2000482       PREFEITURA MUNICIPAL DE RIO BRANCO
# 11                2002132        PREFEITURA MUN DE MAL THAUMATURGO
# 12                2001217           PREFEITURA MUNICIPAL DE XAPURI
# ...

# %%
# 1) Sua solução aqui
qnt_vacinas = df['vacina_nome'].nunique()
qnt_vacinas
# Out:
# 15

# %%
# 2)
pacientes_vacinados = df['paciente_id'].nunique()
pacientes_vacinados
# Out:
# 318850

# %%
# 3)
tipos_dose = df['vacina_descricao_dose'].unique()

pacientes_primeira_dose = df[df['vacina_descricao_dose'].str.contains('1ª|Primeira', na=False)]['paciente_id'].nunique()

pacientes_primeira_dose
# Out:
# 144276

# %%
# 4)
pacientes_menores_18 = df[df['paciente_idade'] < 18]['paciente_id'].nunique()
pacientes_menores_18
# Out:
# 69726

# %%
# 5)
#a coluna estabelecimento_valor apresenta um valor unico para cada estabelecimento
qnt_estabelecimentos = df['estabelecimento_valor'].nunique()
qnt_estabelecimentos
# Out:
# 229

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vacinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)
df_menores_18 = df[df['paciente_idade'] < 18].copy()

# %%
# 2)
colunas_df = df_menores_18.columns.tolist()
colunas_df
# Out:
# ['document_id',
#  'paciente_id',
#  'paciente_idade',
#  'paciente_dataNascimento',
#  'paciente_enumSexoBiologico',
#  'paciente_racaCor_codigo',
#  'paciente_racaCor_valor',
#  'paciente_endereco_coIbgeMunicipio',
#  'paciente_endereco_coPais',
#  'paciente_endereco_nmMunicipio',
#  'paciente_endereco_nmPais',
#  'paciente_endereco_uf',
#  'paciente_endereco_cep',
#  'paciente_nacionalidade_enumNacionalidade',
#  'estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf',
#  'vacina_grupoAtendimento_codigo',
#  'vacina_grupoAtendimento_nome',
#  'vacina_categoria_codigo',
#  'vacina_categoria_nome',
#  'vacina_lote',
#  'vacina_fabricante_nome',
#  'vacina_fabricante_referencia',
#  'vacina_dataAplicacao',
#  'vacina_descricao_dose',
#  'vacina_codigo',
#  'vacina_nome',
#  'sistema_origem']

# %%
# 3)
contagem_vacinas = len(df_menores_18['vacina_categoria_nome'])
contagem_vacinas
# Out:
# 79220

# %%
# 4)
colunas_estabelecimento = ['estabelecimento_valor','estabelecimento_razaoSocial','estalecimento_noFantasia','estabelecimento_municipio_codigo','estabelecimento_municipio_nome','estabelecimento_uf']
df_estabelecimentos = df_menores_18.loc[:, colunas_estabelecimento]
df_estabelecimentos
# Out:
#         estabelecimento_valor               estabelecimento_razaoSocial  \
# 4                     6992811    PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 6                     6917291        PREFEITURA MUNICIPAL DE RIO BRANCO
# 8                     2002922             SECRETARIA MUNICIPAL DE SAUDE
# 10                    2000482        PREFEITURA MUNICIPAL DE RIO BRANCO
# 11                    2002132         PREFEITURA MUN DE MAL THAUMATURGO
# ...                       ...                                       ...
# 390881                2000660  PREFEITURA MUNICIPAL DE SENADOR GUIOMARD
# 390885                5354072            PREFEITURA MUNICIPAL DE JORDAO
# 390892                6934013             PREFEITURA MUNICIPAL DE FEIJO
# 390894                2001225            PREFEITURA MUNICIPAL DE XAPURI
# 390907                6917291        PREFEITURA MUNICIPAL DE RIO BRANCO
#
#                                  estalecimento_noFantasia  \
# ...

# %%
# 5)
df_estabelecimentos_unicos = df_estabelecimentos.drop_duplicates()

vacinas_por_estabelecimento = df_menores_18.groupby(['estabelecimento_razaoSocial']).size().reset_index(name='qtd_vacinas_aplicadas')

df_estabelecimentos_vacinas = df_estabelecimentos_unicos.merge(vacinas_por_estabelecimento, on='estabelecimento_razaoSocial')

df_estabelecimentos_vacinas
# Out:
#      estabelecimento_valor                 estabelecimento_razaoSocial  \
# 0                  6992811      PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 1                  6917291          PREFEITURA MUNICIPAL DE RIO BRANCO
# 2                  2002922               SECRETARIA MUNICIPAL DE SAUDE
# 3                  2000482          PREFEITURA MUNICIPAL DE RIO BRANCO
# 4                  2002132           PREFEITURA MUN DE MAL THAUMATURGO
# ..                     ...                                         ...
# 208                2001357  SECRETARIA MUNICIPAL DE SAUDE DE BRASILEIA
# 209                 783722               SECRETARIA MUNICIPAL DE SAUDE
# 210                2001837          PREFEITURA MUNICIPAL DE RIO BRANCO
# 211                6411312   PREFEITURA MUNICIPAL DE PLACIDO DE CASTRO
# 212                2832798      PREFEITURA MUNICIPAL DE EPITACIOLANDIA
#
#                               estalecimento_noFantasia  \
# 0      UNIDADE BASICA DE SAUDE MANOEL FERNANDES VIEIRA
# ...
